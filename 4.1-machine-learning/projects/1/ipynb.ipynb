# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 데이터셋
#
# 이 작업에서는 [<상수원-취수원 통합 수질 및 녹조 데이터>](https://www.aihub.or.kr/aihubdata/data/view.do?currMenu=115&topMenu=100&aihubDataSe=data&dataSetSn=71352) 데이터를 이용합니다. 리포지토리는 원본 데이터를 포함하지 않으므로, 직접 다운로드하십시오.

# %%
ORIGIN_PATH = './assets/AI-095-1_121_C001_m_T2.csv'

origin = pd.read_csv(ORIGIN_PATH)

# %%
origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1312920 entries, 0 to 1312919
# Data columns (total 47 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   measure_id          1312920 non-null  object
#  1   measure_date        1312920 non-null  object
#  2   turbidity           1312920 non-null  float64
#  3   EC                  1312920 non-null  float64
#  4   pH                  1312920 non-null  float64
#  5   water_temp          0 non-null        float64
#  6   DO                  0 non-null        float64
#  7   TOC                 0 non-null        float64
#  8   algae               0 non-null        float64
#  9   alkalinity          0 non-null        float64
#  10  blue_algae          0 non-null        float64
#  11  residual_Cl         0 non-null        float64
#  12  blue-green_algae    0 non-null        float64
#  13  diatomeae           0 non-null        float64
# ...

# %% [markdown]
# | \# | Column | Count | Non-Null | Dtype |
# | :-: | :-- | :-: | :-: | :-: |
# | 0  | measure_id         | 1312920 | non-null | object |
# | 1  | measure_date       | 1312920 | non-null | object |
# | 2  | turbidity          | 1312920 | non-null | float64 |
# | 3  | EC                 | 1312920 | non-null | float64 |
# | 4  | pH                 | 1312920 | non-null | float64 |
# | 5  | water_temp         | 0 | non-null | float64 |
# | 6  | DO                 | 0 | non-null | float64 |
# | 7  | TOC                | 0 | non-null | float64 |
# | 8  | algae              | 0 | non-null | float64 |
# | 9  | alkalinity         | 0 | non-null | float64 |
# | 10 | blue_algae         | 0 | non-null | float64 |
# | 11 | residual_Cl        | 0 | non-null | float64 |
# | 12 | blue-green_algae   | 0 | non-null | float64 |
# | 13 | diatomeae          | 0 | non-null | float64 |
# | 14 | cryptophyceae      | 0 | non-null | float64 |
# | 15 | 2-MIB              | 0 | non-null | float64 |
# | 16 | Geosmin            | 0 | non-null | float64 |
# | 17 | synedra            | 0 | non-null | float64 |
# | 18 | T-N                | 0 | non-null | float64 |
# | 19 | T-P                | 0 | non-null | float64 |
# | 20 | Mn                 | 0 | non-null | float64 |
# | 21 | temp               | 1312920 | non-null | float64 |
# | 22 | precipitation      | 1312920 | non-null | float64 |
# | 23 | wind_velocity      | 1312920 | non-null | float64 |
# | 24 | up_turbidity       | 1312920 | non-null | float64 |
# | 25 | up_EC              | 1312920 | non-null | float64 |
# | 26 | up_pH              | 1312920 | non-null | float64 |
# | 27 | up_water_temp      | 1312920 | non-null | float64 |
# | 28 | up_DO              | 1312920 | non-null | float64 |
# | 29 | up_TOC             | 1312920 | non-null | float64 |
# | 30 | up_T-N             | 1312920 | non-null | float64 |
# | 31 | up_T-P             | 1312920 | non-null | float64 |
# | 32 | up_water_level     | 1312920 | non-null | int64 |
# | 33 | up_water_volume    | 1312920 | non-null | int64 |
# | 34 | up_water_rates     | 1312920 | non-null | int64 |
# | 35 | up_inflow          | 1312920 | non-null | int64 |
# | 36 | up_total_discharge | 1312920 | non-null | int64 |
# | 37 | up_power_discharge | 1312920 | non-null | int64 |
# | 38 | up_intake          | 1312920 | non-null | int64 |
# | 39 | up_gate_discharge  | 1312920 | non-null | int64 |
# | 40 | p_turbidity        | 1312920 | non-null | int64 |
# | 41 | p_EC               | 1312920 | non-null | int64 |
# | 42 | p_DO               | 1312920 | non-null | int64 |
# | 43 | p_water_temp       | 1312920 | non-null | int64 |
# | 44 | p_TOC              | 1312920 | non-null | int64 |
# | 45 | p_T-N              | 1312920 | non-null | int64 |
# | 46 | p_T-P              | 1312920 | non-null | int64 |

# %%
not_null = [
    "measure_id",
    "measure_date",
    "turbidity",
    "EC",
    "pH",
    "temp",
    "precipitation",
    "wind_velocity",
    "up_turbidity",
    "up_EC",
    "up_pH",
    "up_water_temp",
    "up_DO",
    "up_TOC",
    "up_T-N",
    "up_T-P",
    "up_water_level",
    "up_water_volume",
    "up_water_rates",
    "up_inflow",
    "up_total_discharge",
    "up_power_discharge",
    "up_intake",
    "up_gate_discharge",
    "p_turbidity",
    "p_EC",
    "p_DO",
    "p_water_temp",
    "p_TOC",
    "p_T-N",
    "p_T-P",
]

df = pd.DataFrame(origin[not_null])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1312920 entries, 0 to 1312919
# Data columns (total 31 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   measure_id          1312920 non-null  object
#  1   measure_date        1312920 non-null  object
#  2   turbidity           1312920 non-null  float64
#  3   EC                  1312920 non-null  float64
#  4   pH                  1312920 non-null  float64
#  5   temp                1312920 non-null  float64
#  6   precipitation       1312920 non-null  float64
#  7   wind_velocity       1312920 non-null  float64
#  8   up_turbidity        1312920 non-null  float64
#  9   up_EC               1312920 non-null  float64
#  10  up_pH               1312920 non-null  float64
#  11  up_water_temp       1312920 non-null  float64
#  12  up_DO               1312920 non-null  float64
#  13  up_TOC              1312920 non-null  float64
# ...

# %%
subplots = []
for column in df.columns.values:
    if df[column].dtype == 'object':
        continue
    fig, ax = plt.subplots(figsize=(10, 1))
    ax.set_title(column, fontsize=10)
    box = ax.boxplot(df[column], orientation='horizontal')
    '''for i, each in enumerate(df[column], start=1):
        ax.scatter(
            each, 1, marker='o', color='red'
        )'''
    subplots.append([fig, ax, box])

plt.show()
# Out:
# C:\Users\ShapeLayer\AppData\Local\Temp\ipykernel_25096\52362192.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(10, 1))

# %%
df.drop(columns=["up_water_level", "up_water_volume", "up_water_rates", "up_inflow", "up_total_discharge", "up_power_discharge", "up_intake", "up_gate_discharge"], inplace=True)
df.drop(columns=["p_turbidity", "p_EC", "p_DO", "p_water_temp", "p_TOC", "p_T-N", "p_T-P"], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1312920 entries, 0 to 1312919
# Data columns (total 16 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   measure_id     1312920 non-null  object
#  1   measure_date   1312920 non-null  object
#  2   turbidity      1312920 non-null  float64
#  3   EC             1312920 non-null  float64
#  4   pH             1312920 non-null  float64
#  5   temp           1312920 non-null  float64
#  6   precipitation  1312920 non-null  float64
#  7   wind_velocity  1312920 non-null  float64
#  8   up_turbidity   1312920 non-null  float64
#  9   up_EC          1312920 non-null  float64
#  10  up_pH          1312920 non-null  float64
#  11  up_water_temp  1312920 non-null  float64
#  12  up_DO          1312920 non-null  float64
#  13  up_TOC         1312920 non-null  float64
#  14  up_T-N         1312920 non-null  float64
#  15  up_T-P         1312920 non-null  float64
# ...

# %% [markdown]
# ## 데이터를 과제 요구사항에 맞추기
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 탁도
#
# ![800대 데이터는 존재한다](attachment:image.png)

# %%
def categorize_turbidity(value):
    if value < 0.5:
        return 0
    elif value < 1.0:
        return 1
    elif value < 5.0:
        return 2
    elif value < 25:
        return 3
    elif value < 150:
        return 4
    else:
        return 5

def categorized_turbidity_nameing(value):
    if value == 0:
        return "Drinkable"
    elif value == 1:
        return "Drinkable (Previous)"
    elif value == 2:
        return "Washington Water Body Standard"
    elif value == 3:
        return "Vermont Water Body Standard"
    elif value == 4:
        return "Least Louisiana Water Body Standard"
    else:
        return "Dirtry"

# %%
df
# Out:
#         measure_id      measure_date  turbidity        EC      pH  temp  \
# 0             C001   2020-01-01 0:00     2.6625  285.3125  7.8488  -6.5
# 1             C001   2020-01-01 0:01     2.6000  285.3125  7.8452  -6.5
# 2             C001   2020-01-01 0:02     2.5375  285.5000  7.8470  -6.5
# 3             C001   2020-01-01 0:03     2.6625  285.5000  7.8488  -6.4
# 4             C001   2020-01-01 0:04     2.6625  285.6250  7.8426  -6.4
# ...            ...               ...        ...       ...     ...   ...
# 1312915       C001  2022-06-30 17:55   160.2984  169.8125  7.1960  20.8
# 1312916       C001  2022-06-30 17:56   163.4295  168.6875  7.1960  20.8
# 1312917       C001  2022-06-30 17:57   163.4295  168.6875  7.1960  20.8
# 1312918       C001  2022-06-30 17:58   164.4488  168.5000  7.1916  20.8
# 1312919       C001  2022-06-30 17:59   163.5672  167.6875  7.1916  20.8
#
#          precipitation  wind_velocity  up_turbidity  up_EC  up_pH  \
# ...

# %%
generated = pd.DataFrame(df[["temp", "turbidity"]])
generated["turbidity_cls"] = df["turbidity"].apply(categorize_turbidity)

# %%
generated.head(3)
# Out:
#    temp  turbidity  turbidity_cls
# 0  -6.5     2.6625              2
# 1  -6.5     2.6000              2
# 2  -6.5     2.5375              2

# %%
from random import randint, choice
def drop_random_cell_data(df: pd.DataFrame, n: int = 1000):
    ln_row = len(df)
    for _ in range(n):
        row = randint(0, ln_row - 1)
        col = choice(df.columns.values)
        df.loc[row, col] = np.nan

def fill_na(df: pd.DataFrame):
    df.fillna({
        "temp": df["temp"].mean(),
        "turbidity_cls": df["turbidity_cls"].mean(),
    }, inplace=True)

def apply_noise(df: pd.DataFrame, n: int = 1000):
    drop_random_cell_data(df, n)
    fill_na(df)

# %%
generated.drop(columns=["turbidity"], inplace=True)
drop_random_cell_data(generated, 30000)

# %%
generated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1312920 entries, 0 to 1312919
# Data columns (total 2 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   temp           1298051 non-null  float64
#  1   turbidity_cls  1297952 non-null  float64
# dtypes: float64(2)
# memory usage: 20.0 MB

# %%
fill_na(generated)
generated["turbidity_cls"] = generated["turbidity_cls"].apply(categorize_turbidity)

# %%
generated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1312920 entries, 0 to 1312919
# Data columns (total 2 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   temp           1312920 non-null  float64
#  1   turbidity_cls  1312920 non-null  int64
# dtypes: float64(1), int64(1)
# memory usage: 20.0 MB

# %%
from sklearn.model_selection import train_test_split
y = generated["turbidity_cls"]
X = generated.drop(columns=["turbidity_cls"], axis=1)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=.2, random_state=123
)

# %%
X_train.info()
print(X_train.head(3))
print()
X_test.info()
print()
y_train.info()
print(y_train.head(3))
print()
y_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1050336 entries, 1275615 to 773630
# Data columns (total 1 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   temp    1050336 non-null  float64
# dtypes: float64(1)
# memory usage: 16.0 MB
#          temp
# 1275615  25.9
# 495661    2.4
# 145104   12.9
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 262584 entries, 840614 to 932196
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   temp    262584 non-null  float64
# dtypes: float64(1)
# memory usage: 4.0 MB
#
# <class 'pandas.core.series.Series'>
# Index: 1050336 entries, 1275615 to 773630
# Series name: turbidity_cls
# Non-Null Count    Dtype
# --------------    -----
# 1050336 non-null  int64
# dtypes: int64(1)
# memory usage: 16.0 MB
# 1275615    2
# 495661     2
# 145104     2
# Name: turbidity_cls, dtype: int64
#
# <class 'pandas.core.series.Series'>
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

dt_clf = DecisionTreeClassifier(random_state=11)
rf_clf = RandomForestClassifier(random_state=11)
lr_clf = LogisticRegression()

# %%
dt_clf.fit(X_train, y_train)
dt_pred = dt_clf.predict(X_test)
print("DecisionTreeClassifier Accuracy: %.4f" % accuracy_score(y_test, dt_pred))
# Out:
# DecisionTreeClassifier Accuracy: 0.9930

# %%
rf_clf.fit(X_train , y_train)
rf_pred = rf_clf.predict(X_test)
print("RandomForestClassifier Accuracy: %.4f" % accuracy_score(y_test, rf_pred))
# Out:
# RandomForestClassifier Accuracy: 0.9930

# %%
lr_clf.fit(X_train , y_train)
lr_pred = lr_clf.predict(X_test)
print("LogisticRegression Accuracy: %.4f" % accuracy_score(y_test, lr_pred))
# Out:
# LogisticRegression Accuracy: 0.9930

# %%
from sklearn.model_selection import KFold

def exec_kfold(clf, folds=5):
    kfold = KFold(n_splits=folds)
    scores = []

    for i, (train_idx, test_idx) in enumerate(kfold.split(X)):
        X_train, X_test = X.values[train_idx], X.values[test_idx]
        y_train, y_test = y.values[train_idx], y.values[test_idx]
        clf.fit(X_train, y_train)
        pred = clf.predict(X_test)
        accur = accuracy_score(y_test, pred)
        scores.append(accur)
        print(f"Iteration #{i + 1}, Accuracy: {accur}")
    
    return scores

scores = exec_kfold(dt_clf, folds=5)
print("Mean Accuracy: %.4f" % np.mean(scores))
# Out:
# Iteration #1, Accuracy: 0.9986785181122994
# Iteration #2, Accuracy: 0.9673932912896445
# Iteration #3, Accuracy: 0.9996762940620906
# Iteration #4, Accuracy: 0.9998438594887731
# Iteration #5, Accuracy: 0.9993678213447887
# Mean Accuracy: 0.9930

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(dt_clf, X, y, cv=5)

for i, accur in enumerate(scores):
    print(f"Iteration #{i + 1}, Accuracy: {accur}")
print("Mean Accuracy: %.4f" % np.mean(scores))
# Out:
# Iteration #1, Accuracy: 0.9929927185205496
# Iteration #2, Accuracy: 0.9929927185205496
# Iteration #3, Accuracy: 0.9929927185205496
# Iteration #4, Accuracy: 0.9929927185205496
# Iteration #5, Accuracy: 0.9929889102153977
# Mean Accuracy: 0.9930

# %%
from sklearn.model_selection import GridSearchCV

params = {
    "max_depth": [2, 3, 5, 10],
    "min_samples_split": [2, 3, 5],
    "min_samples_leaf": [1, 2, 3],
}
grid_dclf = GridSearchCV(
    dt_clf, param_grid=params, scoring="accuracy", cv=5
)
grid_dclf.fit(X_train, y_train)

print("GridSearchCV 최적 하이퍼 파라미터: ", grid_dclf.best_params_)
print("GridSearchCV Best Score: ", grid_dclf.best_score_)
print("GridSearchCV Score(): ", grid_dclf.score(X_test, y_test))
print("GridSearchCV Accuracy Score(Predict): ", accuracy_score(y_test, grid_dclf.predict(X_test)))
# Out:
# GridSearchCV 최적 하이퍼 파라미터:  {'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 2}
# GridSearchCV Best Score:  0.9929936705977186
# GridSearchCV Score():  0.9929851019102459
# GridSearchCV Accuracy Score(Predict):  0.9929851019102459
