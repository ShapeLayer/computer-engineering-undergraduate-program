# %%
class Config:
    def __init__(self, samples=1000, seed=214823, noise=.15, split=(.7, .2), epochs=100, batch_size=32):
        self.samples = samples
        self.seed = seed
        self.noise = noise
        try:
            iter(split)
        except TypeError:
            raise ValueError()
        if len(split) != 2:
            raise ValueError()
        self.train_split = int(split[0] * samples)
        self.test_split = int(split[1] * samples + self.train_split)
        self.epochs = epochs
        self.batch_size = batch_size

# %%
import tensorflow as tf
from tensorflow.keras import layers
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
config = Config()

np.random.seed(config.seed)
tf.random.set_seed(config.seed)

# %%
x_vals = np.random.uniform(low=0, high=2 * math.pi, size=config.samples)
np.random.shuffle(x_vals)
y_vals = np.sin(x_vals)
plt.plot(x_vals, y_vals, 'b.')
plt.show()

# %%
y_vals += config.noise * np.random.randn(*y_vals.shape)
plt.plot(x_vals, y_vals, 'b.')
plt.show()

# %%
x_train, x_validate, x_test = np.split(x_vals, [config.train_split, config.test_split])
y_train, y_validate, y_test = np.split(y_vals, [config.train_split, config.test_split])

assert(x_train.size + x_validate.size + x_test.size) == config.samples

plt.plot(x_train, y_train, 'b.', label='Train')
plt.plot(x_validate, y_validate, 'y.', label='Validate')
plt.plot(x_test, y_test, 'r.', label='Test')
plt.legend()
plt.show()

# %%
model = tf.keras.Sequential()
model.add(layers.Dense(32, activation = 'relu', input_shape = (1,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1))
model.compile(optimizer = 'rmsprop', loss = 'mse', metrics = ['mae'])
model.summary()
# Out:
# /opt/anaconda3/envs/embedded/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 16)             │         1,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 28,129 (109.88 KB)
#  Trainable params: 28,129 (109.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(x_train, y_train, epochs = config.epochs, batch_size = config.batch_size, validation_data = (x_validate, y_validate))
# Out:
# Epoch 1/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4421 - mae: 0.5766 - val_loss: 0.2796 - val_mae: 0.4620
# Epoch 2/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2769 - mae: 0.4469 - val_loss: 0.1804 - val_mae: 0.3762
# Epoch 3/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1586 - mae: 0.3311 - val_loss: 0.1593 - val_mae: 0.3503
# Epoch 4/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1201 - mae: 0.2744 - val_loss: 0.1158 - val_mae: 0.2802
# Epoch 5/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1164 - mae: 0.2665 - val_loss: 0.1083 - val_mae: 0.2751
# Epoch 6/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1001 - mae: 0.2476 - val_loss: 0.1822 - val_mae: 0.3541
# Epoch 7/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1156 - mae: 0.2588 - val_loss: 0.1071 - val_mae: 0.2735
# Epoch 8/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0949 - mae: 0.2428 - val_loss: 0.0908 - val_mae: 0.2489
# Epoch 9/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0852 - mae: 0.2309 - val_loss: 0.0882 - val_mae: 0.2450
# Epoch 10/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0807 - mae: 0.2231 - val_loss: 0.0888 - val_mae: 0.2461
# Epoch 11/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0792 - mae: 0.2219 - val_loss: 0.0881 - val_mae: 0.2455
# Epoch 12/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0748 - mae: 0.2144 - val_loss: 0.0791 - val_mae: 0.2309
# Epoch 13/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0720 - mae: 0.2123 - val_loss: 0.0832 - val_mae: 0.2369
# Epoch 14/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0700 - mae: 0.2079 - val_loss: 0.0778 - val_mae: 0.2281
# Epoch 15/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0658 - mae: 0.2011 - val_loss: 0.0774 - val_mae: 0.2274
# Epoch 16/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0648 - mae: 0.1995 - val_loss: 0.0793 - val_mae: 0.2291
# Epoch 17/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0621 - mae: 0.1943 - val_loss: 0.0815 - val_mae: 0.2324
# Epoch 18/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0621 - mae: 0.1942 - val_loss: 0.0864 - val_mae: 0.2414
# Epoch 19/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0622 - mae: 0.1933 - val_loss: 0.0788 - val_mae: 0.2291
# Epoch 20/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0573 - mae: 0.1868 - val_loss: 0.0718 - val_mae: 0.2173
# Epoch 21/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0570 - mae: 0.1869 - val_loss: 0.0569 - val_mae: 0.1905
# Epoch 22/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0498 - mae: 0.1750 - val_loss: 0.0680 - val_mae: 0.2075
# Epoch 23/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0565 - mae: 0.1840 - val_loss: 0.0542 - val_mae: 0.1857
# Epoch 24/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0479 - mae: 0.1697 - val_loss: 0.0675 - val_mae: 0.2098
# Epoch 25/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0485 - mae: 0.1723 - val_loss: 0.0627 - val_mae: 0.2019
# Epoch 26/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0474 - mae: 0.1691 - val_loss: 0.0712 - val_mae: 0.2151
# Epoch 27/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0509 - mae: 0.1764 - val_loss: 0.0523 - val_mae: 0.1825
# Epoch 28/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0449 - mae: 0.1659 - val_loss: 0.0637 - val_mae: 0.2028
# Epoch 29/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0485 - mae: 0.1722 - val_loss: 0.0499 - val_mae: 0.1784
# Epoch 30/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0427 - mae: 0.1631 - val_loss: 0.0605 - val_mae: 0.1961
# Epoch 31/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0486 - mae: 0.1710 - val_loss: 0.0473 - val_mae: 0.1736
# Epoch 32/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0425 - mae: 0.1618 - val_loss: 0.0497 - val_mae: 0.1780
# Epoch 33/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0424 - mae: 0.1608 - val_loss: 0.0492 - val_mae: 0.1771
# Epoch 34/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0426 - mae: 0.1623 - val_loss: 0.0461 - val_mae: 0.1716
# Epoch 35/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0414 - mae: 0.1604 - val_loss: 0.0461 - val_mae: 0.1716
# Epoch 36/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0413 - mae: 0.1607 - val_loss: 0.0435 - val_mae: 0.1666
# Epoch 37/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0399 - mae: 0.1571 - val_loss: 0.0467 - val_mae: 0.1724
# Epoch 38/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0409 - mae: 0.1591 - val_loss: 0.0410 - val_mae: 0.1618
# Epoch 39/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0388 - mae: 0.1545 - val_loss: 0.0484 - val_mae: 0.1757
# Epoch 40/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0413 - mae: 0.1596 - val_loss: 0.0420 - val_mae: 0.1636
# Epoch 41/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0394 - mae: 0.1561 - val_loss: 0.0451 - val_mae: 0.1697
# Epoch 42/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0397 - mae: 0.1569 - val_loss: 0.0409 - val_mae: 0.1614
# Epoch 43/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0385 - mae: 0.1542 - val_loss: 0.0468 - val_mae: 0.1729
# Epoch 44/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0398 - mae: 0.1565 - val_loss: 0.0460 - val_mae: 0.1713
# Epoch 45/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0395 - mae: 0.1559 - val_loss: 0.0443 - val_mae: 0.1683
# Epoch 46/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0389 - mae: 0.1546 - val_loss: 0.0452 - val_mae: 0.1699
# Epoch 47/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0390 - mae: 0.1549 - val_loss: 0.0445 - val_mae: 0.1688
# Epoch 48/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0387 - mae: 0.1542 - val_loss: 0.0440 - val_mae: 0.1677
# Epoch 49/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0386 - mae: 0.1540 - val_loss: 0.0447 - val_mae: 0.1690
# Epoch 50/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0386 - mae: 0.1537 - val_loss: 0.0443 - val_mae: 0.1683
# Epoch 51/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0384 - mae: 0.1532 - val_loss: 0.0424 - val_mae: 0.1646
# Epoch 52/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0372 - mae: 0.1512 - val_loss: 0.0425 - val_mae: 0.1649
# Epoch 53/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0375 - mae: 0.1521 - val_loss: 0.0407 - val_mae: 0.1612
# Epoch 54/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0371 - mae: 0.1515 - val_loss: 0.0415 - val_mae: 0.1628
# Epoch 55/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0374 - mae: 0.1520 - val_loss: 0.0388 - val_mae: 0.1573
# Epoch 56/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0363 - mae: 0.1500 - val_loss: 0.0406 - val_mae: 0.1609
# Epoch 57/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0367 - mae: 0.1505 - val_loss: 0.0395 - val_mae: 0.1587
# Epoch 58/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0363 - mae: 0.1498 - val_loss: 0.0404 - val_mae: 0.1607
# Epoch 59/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0367 - mae: 0.1504 - val_loss: 0.0385 - val_mae: 0.1565
# Epoch 60/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0360 - mae: 0.1492 - val_loss: 0.0383 - val_mae: 0.1564
# Epoch 61/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0360 - mae: 0.1491 - val_loss: 0.0385 - val_mae: 0.1565
# Epoch 62/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0357 - mae: 0.1487 - val_loss: 0.0382 - val_mae: 0.1558
# Epoch 63/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0356 - mae: 0.1486 - val_loss: 0.0389 - val_mae: 0.1575
# Epoch 64/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0356 - mae: 0.1485 - val_loss: 0.0382 - val_mae: 0.1559
# Epoch 65/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0355 - mae: 0.1481 - val_loss: 0.0377 - val_mae: 0.1548
# Epoch 66/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0352 - mae: 0.1479 - val_loss: 0.0379 - val_mae: 0.1552
# Epoch 67/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0352 - mae: 0.1477 - val_loss: 0.0373 - val_mae: 0.1539
# Epoch 68/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0346 - mae: 0.1464 - val_loss: 0.0378 - val_mae: 0.1552
# Epoch 69/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0349 - mae: 0.1473 - val_loss: 0.0369 - val_mae: 0.1532
# Epoch 70/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0346 - mae: 0.1468 - val_loss: 0.0368 - val_mae: 0.1529
# Epoch 71/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0347 - mae: 0.1470 - val_loss: 0.0366 - val_mae: 0.1526
# Epoch 72/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0345 - mae: 0.1466 - val_loss: 0.0372 - val_mae: 0.1538
# Epoch 73/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0348 - mae: 0.1473 - val_loss: 0.0366 - val_mae: 0.1525
# Epoch 74/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0346 - mae: 0.1467 - val_loss: 0.0370 - val_mae: 0.1533
# Epoch 75/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0345 - mae: 0.1465 - val_loss: 0.0366 - val_mae: 0.1524
# Epoch 76/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0344 - mae: 0.1463 - val_loss: 0.0376 - val_mae: 0.1545
# Epoch 77/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0345 - mae: 0.1465 - val_loss: 0.0361 - val_mae: 0.1512
# Epoch 78/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0342 - mae: 0.1459 - val_loss: 0.0370 - val_mae: 0.1533
# Epoch 79/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0342 - mae: 0.1458 - val_loss: 0.0362 - val_mae: 0.1515
# Epoch 80/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0343 - mae: 0.1462 - val_loss: 0.0359 - val_mae: 0.1510
# Epoch 81/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0341 - mae: 0.1458 - val_loss: 0.0360 - val_mae: 0.1510
# Epoch 82/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0341 - mae: 0.1457 - val_loss: 0.0356 - val_mae: 0.1503
# Epoch 83/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0339 - mae: 0.1453 - val_loss: 0.0353 - val_mae: 0.1498
# Epoch 84/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0338 - mae: 0.1451 - val_loss: 0.0356 - val_mae: 0.1502
# Epoch 85/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0339 - mae: 0.1454 - val_loss: 0.0359 - val_mae: 0.1509
# Epoch 86/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0339 - mae: 0.1454 - val_loss: 0.0352 - val_mae: 0.1495
# Epoch 87/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0337 - mae: 0.1449 - val_loss: 0.0355 - val_mae: 0.1500
# Epoch 88/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0339 - mae: 0.1453 - val_loss: 0.0348 - val_mae: 0.1485
# Epoch 89/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0336 - mae: 0.1447 - val_loss: 0.0344 - val_mae: 0.1478
# Epoch 90/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0334 - mae: 0.1444 - val_loss: 0.0352 - val_mae: 0.1495
# Epoch 91/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0336 - mae: 0.1447 - val_loss: 0.0352 - val_mae: 0.1494
# Epoch 92/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0337 - mae: 0.1447 - val_loss: 0.0348 - val_mae: 0.1484
# Epoch 93/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0335 - mae: 0.1446 - val_loss: 0.0350 - val_mae: 0.1487
# Epoch 94/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0334 - mae: 0.1444 - val_loss: 0.0353 - val_mae: 0.1496
# Epoch 95/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0335 - mae: 0.1446 - val_loss: 0.0348 - val_mae: 0.1485
# Epoch 96/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0333 - mae: 0.1441 - val_loss: 0.0347 - val_mae: 0.1483
# Epoch 97/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0333 - mae: 0.1443 - val_loss: 0.0353 - val_mae: 0.1493
# Epoch 98/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0333 - mae: 0.1441 - val_loss: 0.0347 - val_mae: 0.1482
# Epoch 99/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0332 - mae: 0.1443 - val_loss: 0.0352 - val_mae: 0.1492
# Epoch 100/100
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0333 - mae: 0.1442 - val_loss: 0.0346 - val_mae: 0.1480

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'g.', label='Training loss')
plt.plot(epochs, val_loss, 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
SKIP = 10
plt.plot(epochs[SKIP:], loss[SKIP:], 'g.', label='Training loss')
plt.plot(epochs[SKIP:], val_loss[SKIP:], 'b.', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
mae = history.history['mae']
val_mae = history.history['val_mae']
plt.plot(epochs[SKIP:], mae[SKIP:], 'g.', label='Training MAE')
plt.plot(epochs[SKIP:], val_mae[SKIP:], 'b.', label='Validation MAE')
plt.title('Training and validation mean absolute error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
pred = model.predict(x_test)
plt.clf()
plt.title('Comparison of predictions and actual values')
plt.plot(x_test, y_test, 'b.', label='Actual')
plt.plot(x_test, pred, 'r.', label='Predicted')
plt.legend()
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
